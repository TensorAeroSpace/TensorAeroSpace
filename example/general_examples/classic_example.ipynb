# %% [markdown]
# # 🚀 Classic Example: IHDP/Actor-Critic for F-16 (Linear Longitudinal Model)
#
# A concise, GitHub-friendly example of online Actor-Critic (IHDP/ADP) training for F-16 longitudinal dynamics: model setup, reference signal generation, actor/critic configuration, training loop execution, and metrics evaluation.

# %% [markdown]
# ## 📋 Table of Contents
# - [📖 Introduction](#📖-Introduction)
# - [📦 Imports](#📦-Imports)
# - [🔧 Experiment Parameters](#🔧-Experiment-Parameters)
# - [🧠 Actor, Critic, and Incremental Model](#🧠-Actor,-Critic,-and-Incremental-Model)
# - [✈️ F-16 Environment Initialization](#✈️-F-16-Environment-Initialization)
# - [🔄 Training Loop](#🔄-Training-Loop)
# - [📊 Metrics](#📊-Metrics)
# - [📈 Visualization](#📈-Visualization)
# - [💡 Tips and Diagnostics](#💡-Tips-and-Diagnostics)
# - [📄 License](#📄-License)

# %% [markdown]
# ## 📖 Introduction
# Demonstration of IHDP/Actor-Critic for angle-of-attack (alpha) tracking in a linear longitudinal F-16 model. This example is designed for clarity and reproducibility.
#
# ### 🧠 What is IHDP/Actor-Critic?
# **IHDP (Incremental Heuristic Dynamic Programming)** is an adaptive control method based on dynamic programming principles. The algorithm consists of three key components:
#
# 1. **Actor** — a neural network that generates control actions based on the current system state and the desired reference signal
# 2. **Critic** — a neural network that evaluates control quality through a value function
# 3. **Incremental Model** — a model that identifies local system dynamics in real time
#
# ### ✈️ F-16 Control Task
# In this example we solve the angle-of-attack (alpha) tracking problem for a linear longitudinal F-16 fighter model. The control system must ensure precise tracking of the reference signal while respecting physical constraints.
#
# **Main algorithm steps:**
# - Configure the time scale and reference signal (5 deg step);
# - Select observed states (alpha, q) and control channel (stabilizer);
# - Initialize and train the Actor, Critic, and IncrementalModel;
# - Run online closed-loop training on the linear F-16 model;
# - Analyze control quality metrics and visualize results.

# %% [markdown]
# ## 📦 Imports
#
# Loading the required libraries for the IHDP/Actor-Critic algorithm:
#
# - **tqdm** — progress bar during training
# - **numpy** — numerical computations and array operations
# - **Actor, Critic, IncrementalModel** — core IHDP algorithm components
# - **LongitudinalF16** — linear longitudinal F-16 fighter model
# - **sinusoid** — sinusoidal signal generator for reference trajectories

# %%
from tqdm import tqdm
import numpy as np

from tensoraerospace.agent.ihdp.Actor import Actor
from tensoraerospace.agent.ihdp.Critic import Critic
from tensoraerospace.agent.ihdp.Incremental_model import IncrementalModel

from tensoraerospace.aerospacemodel.f16.linear.longitudinal import (
    set_initial_state, initial_state, LongitudinalF16
)
from tensoraerospace.signals import sinusoid

# %% [markdown]
# ## 🔧 Experiment Parameters
#
# Defining key parameters for the F-16 control experiment:
#
# ### ⏰ Time Parameters
# - **t0, tn, dt** — time boundaries and discretization step for numerical integration
# - **number_time_steps** — total number of simulation time steps
# - **time** — array of time stamps for plotting
#
# ### 📊 Reference Signal
# The desired trajectory for the angle of attack. In this example a 5 deg step signal is applied at the 1000th step (t=10s), simulating a pilot command to change the angle of attack.
#
# ### 🎯 State and Control Vector Composition
# - **selected_states** — observed state variables (alpha - angle of attack, q - pitch rate)
# - **selected_input** — control inputs (stab - stabilizer deflection)
# - **tracking_states** — variables being tracked (alpha only)
# - **input_magnitude_limits, input_rate_limits** — physical control constraints

# %%
# Time parameters
t0 = 0.0     # initial time, s
tn = 20.0    # simulation time, s
dt = 0.01    # discretization step, s
number_time_steps = int(((tn - t0) / dt) + 1)

# Time scale
time = list(np.arange(0, number_time_steps * dt, dt))
# t is used by unit_step as an index scale (for a step at sample 1000)
t = np.linspace(0, len(time), len(time))

# Reference signal: pick one of the options below
# reference_signals = np.reshape([np.deg2rad(1) for _ in time], [1, -1])
# reference_signals = np.reshape(np.deg2rad(sinusoid(time, 5, 5)), [1, -1])

def unit_step(x):
    return np.deg2rad(5) * (x > 1000)

reference_signals = np.reshape(unit_step(t), [1, -1])

# %%
# State/action vector composition and limits
selected_states = ['alpha', 'q']
selected_input = ['stab']
input_magnitude_limits = 25   # control action magnitude limit, deg
input_rate_limits = 60        # rate limit, deg/s
tracking_states = ['alpha']

# Tracking indices for fast access
indices_tracking_states = [selected_states.index(s) for s in tracking_states]

# %% [markdown]
# ## 🧠 Actor, Critic, and Incremental Model
#
# Configuring the three key IHDP algorithm components with detailed parameter explanations:
#
# ### 🎭 Actor Parameters
# - **actor_start_training** — step at which actor training begins (5-step delay for stabilization)
# - **actor_layers** — neural network architecture (25 neurons in hidden layer, 1 output)
# - **actor_activations** — activation functions ('tanh' for nonlinearity)
# - **actor_learning_rate** — learning rate with adaptive decay
# - **type_PE** — type of persistent excitation signal for state-space exploration
# - **amplitude_3211, pulse_length_3211** — 3-2-1-1 excitation signal parameters
# - **maximum_input, maximum_q_rate** — physical control constraints
#
# ### 🎯 Critic Parameters
# - **Q_weights** — cost function weights for penalizing reference deviation
# - **gamma** — discount factor for future rewards (0.99)
# - **critic_learning_rate** — critic learning rate
# - **critic_layers** — critic network architecture (25 neurons, linear output)
# - **critic_activations** — activations ('tanh' + 'linear' for value estimation)
#
# ### ⚡ Incremental Model
# Identifies local system dynamics in real time using the least-squares method to estimate the system Jacobian matrix.

# %%
# Actor parameters
actor_start_training = 5
actor_layers = (25, 1)
actor_activations = ('tanh', 'tanh')
actor_learning_rate = 2
actor_learning_rate_cascaded = 1.2
actor_learning_rate_exponent_limit = 10

# Excitation (PE)
type_PE = 'combined'
amplitude_3211 = 15
pulse_length_3211 = 5 / dt

# Limits
maximum_input = 25
maximum_q_rate = 20

# Other
cascaded_actor = False
WB_limits = 30
NN_initial = 130

# %%
# Critic parameters
Q_weights = [8]
tracking_states = ['alpha']
critic_start_training = -1
gamma = 0.99
critic_learning_rate = 15
critic_learning_rate_exponent_limit = 10
critic_layers = (25, 1)
critic_activations = ('tanh', 'linear')

# %%
# Initialize and assemble the models
actor = Actor(selected_input, selected_states, tracking_states, indices_tracking_states,
              number_time_steps, actor_start_training, actor_layers, actor_activations,
              actor_learning_rate, actor_learning_rate_cascaded, actor_learning_rate_exponent_limit,
              type_PE, amplitude_3211, pulse_length_3211, WB_limits,
              maximum_input, maximum_q_rate, cascaded_actor, NN_initial)
actor.build_actor_model()

critic = Critic(Q_weights, selected_states, tracking_states, indices_tracking_states,
               number_time_steps, critic_start_training, gamma,
               critic_learning_rate, critic_learning_rate_exponent_limit,
               critic_layers, critic_activations, WB_limits, NN_initial)
critic.build_critic_model()

incremental_model = IncrementalModel(selected_states, selected_input, number_time_steps, dt,
                                     input_magnitude_limits, input_rate_limits)

# %% [markdown]
# ## ✈️ F-16 Environment Initialization
#
# Setting up the linear longitudinal F-16 fighter model for the experiment:
#
# ### 🎯 Initial Conditions
# - **alpha_states** — array for storing the angle-of-attack history during simulation
# - **initial_state** — initial system state with 3 deg angle of attack (typical cruise value)
# - **model** — instance of the linear longitudinal F-16 model with selected output variables
#
# ### 🛩️ LongitudinalF16 Model
# The linear longitudinal F-16 model describes aircraft motion in the vertical plane and includes:
# - **State variables**: alpha (angle of attack), q (pitch rate), theta (pitch angle), h (altitude)
# - **Control inputs**: delta_e (stabilizer deflection), delta_t (throttle position)
# - **Linearization**: the model is linearized about steady-level flight at a given altitude and speed
#
# In this example we observe only alpha and q, and control only the stabilizer (delta_e), simplifying the control task to a two-dimensional system.

# %%
# Initial conditions and F-16 model creation (linear longitudinal)
alpha_states = []
initial_state = set_initial_state({'alpha': np.deg2rad(3)})
model = LongitudinalF16(initial_state, number_time_steps, selected_state_output=['alpha', 'q'])

# %% [markdown]
# ## 🔄 Training Loop
#
# The main IHDP/Actor-Critic online training loop, executed at each time step:
#
# ### 📋 Algorithm at each step:
# 1. **Control generation** — Actor computes control action ut based on current state xt and reference xt_ref
# 2. **Model identification** — IncrementalModel updates the local linear model via least squares
# 3. **State prediction** — Prediction of the next state xt+1 based on the identified model
# 4. **Critic training** — Critic weight update to improve the value function estimate
# 5. **Actor training** — Actor policy correction based on the value function gradient
# 6. **Attribute update** — Saving history for the next iteration
# 7. **Model step** — One integration step of the F-16 model with the computed control
#
# ### ⭐ Key Features:
# - **Online learning**: neural network weights are updated in real time
# - **Adaptive learning rates**: exponential decay is used for stabilization
# - **Physical constraints**: control is bounded by realistic stabilizer limits
# - **Excitation signal**: added to ensure state-space exploration

# %%
# Main online-training loop
xt = np.array([[np.deg2rad(3)], [0]])
alpha_series = []
alpha_ref_series = []
u_series = []

for time_step in tqdm(range(number_time_steps - 1)):
    xt_ref = np.reshape(reference_signals[:, time_step], [-1, 1])

    ut = actor.run_actor_online(xt, xt_ref)
    u_series.append(float(ut))

    # Incremental model identification and prediction
    G = incremental_model.identify_incremental_model_LS(xt, ut)
    xt1_est = incremental_model.evaluate_incremental_model()

    # Critic and actor training
    xt_ref1 = np.reshape(reference_signals[:, time_step + 1], [-1, 1])
    _ = critic.run_train_critic_online_alpha_decay(xt, xt_ref)
    Jt1, dJt1_dxt1 = critic.evaluate_critic(np.reshape(xt1_est, [-1, 1]), xt_ref1)
    actor.train_actor_online_alpha_decay(Jt1, dJt1_dxt1, G, incremental_model, critic, xt_ref1)

    # Attribute updates
    incremental_model.update_incremental_model_attributes()
    critic.update_critic_attributes()
    actor.update_actor_attributes()

    # Model step
    xt = model.run_step(ut)
    alpha_series.append(float(model.get_state('alpha')[-1]))
    alpha_ref_series.append(float(xt_ref[0]))

# %% [markdown]
# ## 📊 Metrics
#
# Evaluating control quality using key performance indicators:
#
# ### 📏 Static Error
# The difference between the commanded and achieved angle of attack in steady state, measured in degrees. Shows the accuracy of the control system in the stationary regime. Ideal value: 0 deg.
#
# ### 📈 Overshoot
# The maximum exceedance of the commanded value during the transient process, expressed as a percentage of the steady-state value. Characterizes system stability:
# - **< 5%** — excellent control quality
# - **5-15%** — acceptable quality
# - **> 15%** — parameter tuning required
#
# ### 🔍 Analysis Range
# Overshoot is computed over steps 1000-15000, corresponding to the period after the step signal until the transient settles.

# %%
# Steady-state error and overshoot for angle of attack (in degrees)
static_error_deg = np.rad2deg(reference_signals[0][-1] - model.get_state('alpha')[-1])
overshoot_pct = (
    (np.max(model.get_state('alpha')[1000:15000]) - reference_signals[0][1001])
    * 100 / reference_signals[0][1001]
)
print(f"Steady-state error: {static_error_deg} deg.")
print(f"Overshoot: {overshoot_pct} %")

# %% [markdown]
# ## 📈 Visualization
#
# Plotting graphs to analyze control quality and system behavior:
#
# ### 📊 Angle-of-Attack Tracking Plot
# The main experiment result — comparing the actual angle-of-attack trajectory (solid line) with the reference signal (dashed line).
#
# **What to look for:**
# - **Settling time** — how quickly the system reaches the target after the step at the 1000th step
# - **Overshoot** — maximum exceedance of the target value (5 deg) during the transient
# - **Steady-state error** — difference between commanded and actual values at the end of the simulation
# - **Oscillations** — presence of oscillations around the target value
#
# ### 🔍 Interpreting Results
# - **Good quality**: smooth transient with minimal overshoot, fast convergence to the target
# - **Needs improvement**: large oscillations, slow convergence, significant steady-state error
#
# Additionally, you can plot the control signal `u_series` and the cost function for a more detailed analysis.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 4))
plt.plot(np.rad2deg(alpha_series), label='alpha (deg)')
plt.plot(np.rad2deg(alpha_ref_series), '--', label='reference (deg)')
plt.xlabel('Step')
plt.ylabel('Degrees')
plt.title('Angle-of-attack tracking (alpha)')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## 💡 Tips and Diagnostics
#
# Recommendations for tuning and debugging the IHDP/Actor-Critic algorithm:
#
# ### 📊 Reference Signal Tuning
# - **Step signal**: `unit_step(t)` — for analyzing transient processes and settling time
# - **Sinusoidal signal**: `sinusoid(time, amplitude, frequency)` — for verifying tracking of periodic commands
# - **Constant signal**: `np.deg2rad(constant_value)` — for analyzing steady-state accuracy
#
# ### ⚖️ Cost Function Weight Tuning
# - **Q_weights**: increase for more aggressive tracking, decrease for smoother control
# - **tracking_states**: you can add 'q' for simultaneous control of angle of attack and pitch rate
# - **gamma**: discount factor (0.95-0.99) affects the planning horizon
#
# ### 🧠 Neural Network Architecture
# - **Layer size**: start with 25 neurons, increase for complex tasks (50-100)
# - **Activation functions**: 'tanh' for hidden layers, 'linear' for the critic output layer
# - **Learning rates**: decrease for instability, increase for slow convergence
#
# ### ⚙️ Physical Constraints
# - **maximum_input**: maximum stabilizer deflection (typically +/-25 deg)
# - **maximum_q_rate**: pitch rate limit to prevent abrupt maneuvers
# - **input_rate_limits**: control rate limit for realism
#
# ### 🔧 Troubleshooting
# - **Instability**: reduce learning rates, check constraints
# - **Slow convergence**: increase Q_weights, check the excitation signal
# - **Large overshoot**: reduce actor aggressiveness, tune the critic
# - **Reproducibility**: set numpy.random.seed() at the beginning of the experiment
#
# ### 📋 Additional Diagnostics
# For deeper analysis, save and visualize:
# - Control signal history `u_series`
# - State trajectories `xt` (angle of attack and pitch rate)
# - Cost function values `Jt` to monitor critic training
# - Neural network weights for convergence analysis

# %% [markdown]
# ## 📄 License
# This example is distributed under the project license (see the LICENSE file in the repository root).
