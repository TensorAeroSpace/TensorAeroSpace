# %% [markdown]
# # iADP: updated implementation
#
# The previous example used the removed implementation. Run the [updated executable notebook](example_iadp_paper.ipynb), which contains freshly evaluated plots and metrics for the current algorithm. Historical outputs are retained in this file's git history.
#
# AA-INDI now requires independent navigation and physical geometry. iADP now uses the published unregularized critic. Previous numerical results are not claims about these new controllers.
