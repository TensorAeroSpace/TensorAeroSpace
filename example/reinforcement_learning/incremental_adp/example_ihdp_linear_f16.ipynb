# %%
import numpy as np
from tqdm import tqdm

from tensoraerospace.envs.f16.linear_longitudinal import LinearLongitudinalF16
from tensoraerospace.utils import generate_time_period, convert_tp_to_sec_tp
from tensoraerospace.signals.standard import unit_step
from tensoraerospace.agent.ihdp.model import IHDPAgent
from tensoraerospace.benchmark import ControlBenchmark

# %% [markdown]
# ## Imports
#
# Load core libraries, the F-16 environment, signal generators, the IHDPAgent model, and the ControlBenchmark for evaluating transient response quality.
#
# **Paper-equation update:** the SISO actor gradient now includes the physical output scale. The actor learning rate and its floor are expressed in these units. Previous cached results were cleared; execute this notebook to obtain results with the current implementation.

# %% [markdown]
# # IHDP Agent for F-16 Angle-of-Attack Tracking
#
# This notebook demonstrates the **IHDPAgent** wrapper for Incremental Heuristic Dynamic Programming applied to the `LinearLongitudinalF16-v0` Gymnasium environment. A step reference signal for the angle of attack (alpha) is tracked, and the transient response is evaluated using `ControlBenchmark`.

# %%
dt = 0.01  # Discretization
tp = generate_time_period(tn=20, dt=dt) # Time period
tps = convert_tp_to_sec_tp(tp, dt=dt)
number_time_steps = len(tp) # Number of time steps
reference_signals = np.reshape(unit_step(degree=5, tp=tp, time_step=1000*dt, output_rad=True), [1, -1]) # Reference signal

# %% [markdown]
# ## Simulation Parameters and Reference Signal
#
# Define the discretization step, time period, and a 5-degree unit step reference signal applied at step 1000.

# %%
import gymnasium as gym

# initial_state matches only the selected states
initial_state = [ [0], [0], [0]]  # For theta, alpha, q

env = gym.make('LinearLongitudinalF16-v0', 
               number_time_steps=number_time_steps, 
               initial_state=initial_state,  # 3 elements for 3 states
               reference_signal=reference_signals, use_reward=False,
               state_space= ["theta", "alpha", "q"],
               output_space=["theta", "alpha", "q" ], 
               control_space=["ele"], 
               tracking_states=["alpha"])
env.reset()

# %% [markdown]
# ## Environment Setup
#
# Create the `LinearLongitudinalF16-v0` Gymnasium environment with three state variables (theta, alpha, q), elevator control, and alpha as the tracking target.

# %%
actor_settings = {
    "start_training": 5,
    "layers": (25, 1), 
    "activations":  ('tanh', 'tanh'), 
    "learning_rate": 2.0 / 25.0,
    "learning_rate_min": 0.001 / 25.0, 
    "learning_rate_exponent_limit": 10,
    "type_PE": "combined",
    "amplitude_3211": 15, 
    "pulse_length_3211": 5/dt, 
    "maximum_input": 25,
    "maximum_q_rate": 20,
    "WB_limits": 30,
    "NN_initial": 120,
    "cascade_actor": False,
    "learning_rate_cascaded":1.2
}

# %% [markdown]
# ## IHDP Agent Configuration
#
# Configure the Actor, Critic, and Incremental Model settings, then instantiate the IHDPAgent.

# %%
incremental_settings = {
    "number_time_steps": number_time_steps, 
    "dt": dt, 
    "input_magnitude_limits":25, 
    "input_rate_limits":60,
}

# %%
critic_settings = {
    "Q_weights": [8], 
    "start_training": -1, 
    "gamma": 0.99, 
    "learning_rate": 15, 
    "learning_rate_exponent_limit": 10,
    "layers": (25,1), 
    "activations": ("tanh", "linear"), 
        "WB_limits": 30,
    "NN_initial": 120,
    "indices_tracking_states": env.unwrapped.indices_tracking_states
}

# %%
model = IHDPAgent(actor_settings, critic_settings, incremental_settings, env.unwrapped.tracking_states, env.unwrapped.state_space, env.unwrapped.control_space, number_time_steps, env.unwrapped.indices_tracking_states)

# %%
xt = np.array([[0], [0], [0]])

for step in tqdm(range(number_time_steps-3)):
    ut = model.predict(xt, reference_signals, step)
    xt, reward, terminated, truncated, info = env.step(np.array(ut))

# %% [markdown]
# ## Training Loop
#
# Run the online IHDP training loop. At each time step the agent predicts a control action and the environment advances one step.

# %%
env.unwrapped.model.plot_transient_process('alpha', tps, reference_signals[0], to_deg=True, figsize=(15,4))

# %% [markdown]
# ## Visualization
#
# Plot the transient response for alpha, theta, and the pitch rate q to inspect how well the controller tracks the reference.

# %%
env.unwrapped.model.plot_transient_process('theta', tps, reference_signals[0], to_deg=True, figsize=(15,4))

# %%
env.unwrapped.model.plot_state(state_name='q', time=tps, to_deg=True, figsize=(15,4))

# %% [markdown]
# ## Transient Response Evaluation
#
# Use `ControlBenchmark` to compute standard control quality metrics: static error, settling time, damping degree, and overshoot. These metrics quantify how accurately and quickly the system reaches the commanded angle of attack.

# %%
system_signal_orig = env.unwrapped.model.get_state('alpha', to_deg=True)[:2000]
control_signal_orig = np.rad2deg(reference_signals[0])[:2000]

# %%
bench = ControlBenchmark()

# %%
res = bench.becnchmarking_one_step(control_signal_orig, system_signal_orig, 1, dt)

# %%
print("Steady-state error: ", res['static_error'])
print("Settling time: ", res['settling_time'], "sec")
print("Damping degree: ", res['damping_degree'])
print("Overshoot: ", res['overshoot'])

# %%
bench.plot(control_signal_orig, system_signal_orig, 1, dt, tps, figsize=(15,5))
