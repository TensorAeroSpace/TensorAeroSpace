# %% [markdown]
# # 🚀 Example: Working with ImprovedELVEnv
#
# This notebook demonstrates the usage of the improved ELV launch vehicle environment with normalized spaces.
#
# ## 📋 Features of ImprovedELVEnv:
# - ✅ Normalized action and observation spaces [-1, 1]
# - ✅ Improved reward function
# - ✅ Optimized for reinforcement learning

# %% [markdown]
# ## 📚 Importing Libraries

# %%
import gymnasium as gym
import numpy as np
import tensoraerospace
from tensoraerospace.utils import generate_time_period, convert_tp_to_sec_tp
from tensoraerospace.signals.standart import unit_step

# %% [markdown]
# ## ⚙️ Parameters Setup

# %%
dt = 0.01
tp = generate_time_period(tn=20, dt=dt)
number_time_steps = len(tp)
reference_signals = np.reshape(
    unit_step(degree=5, tp=tp, time_step=10, output_rad=True), 
    [1, -1]
)
print(f"📊 Параметры: время={tp[-1]:.1f}с, шагов={number_time_steps}")
# Out:
# 📊 Параметры: время=2002.0с, шагов=2002

# %% [markdown]
# ## 🚀 Creating the Environment

# %%
# Начальное состояние [w, q, theta] в м/с, рад/с, рад
initial_state = np.array([0.0, 0.0, 0.0])

env = gym.make(
    "ImprovedELV-v0",
    initial_state=initial_state,
    reference_signal=reference_signals,
    number_time_steps=number_time_steps,
    dt=dt,
    initial_elevator_deg=0.0
)

obs, info = env.reset()
print(f"✅ Среда создана!")
print(f"📊 Наблюдение: {obs}")
print(f"🎯 Действия: {env.action_space}")
print(f"📐 Наблюдения: {env.observation_space}")
# Out:
# ✅ Среда создана!
# 📊 Наблюдение: [0. 0. 0. 0.]
# 🎯 Действия: Box(-1.0, 1.0, (1,), float32)
# 📐 Наблюдения: Box(-1.0, 1.0, (4,), float32)

# %% [markdown]
# ## 🎮 Executing a Step

# %%
action = np.array([0.5], dtype=np.float32)
obs, reward, terminated, truncated, info = env.step(action)
print(f"🎯 Действие: {action[0]:.2f}")
print(f"📊 Наблюдение: {obs}")
print(f"🏆 Награда: {reward:.6f}")
# Out:
# 🎯 Действие: 0.50
# 📊 Наблюдение: [0. 0. 0. 0.]
# 🏆 Награда: -0.000000
